# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
## load dataset
Earthquake = pd.read_csv('all_month.csv')
Earthquake
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666    2.16  1.44      md
# 1      2022-10-18T12:49:51.309Z  61.416000 -149.833400   25.70  1.50      ml
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167   27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667    1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000    8.26  2.94      md
# ...                         ...        ...         ...     ...   ...     ...
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833    4.98  1.89      ml
# 10337  2022-09-18T12:59:27.558Z  61.431000 -147.277300  139.90  2.30      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000    5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333    5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600   10.00  4.50      mb
#
# ...

# %%
Earthquake.head()
Earthquake
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666    2.16  1.44      md
# 1      2022-10-18T12:49:51.309Z  61.416000 -149.833400   25.70  1.50      ml
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167   27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667    1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000    8.26  2.94      md
# ...                         ...        ...         ...     ...   ...     ...
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833    4.98  1.89      ml
# 10337  2022-09-18T12:59:27.558Z  61.431000 -147.277300  139.90  2.30      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000    5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333    5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600   10.00  4.50      mb
#
# ...

# %%
Earthquake.tail()
Earthquake
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666    2.16  1.44      md
# 1      2022-10-18T12:49:51.309Z  61.416000 -149.833400   25.70  1.50      ml
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167   27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667    1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000    8.26  2.94      md
# ...                         ...        ...         ...     ...   ...     ...
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833    4.98  1.89      ml
# 10337  2022-09-18T12:59:27.558Z  61.431000 -147.277300  139.90  2.30      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000    5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333    5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600   10.00  4.50      mb
#
# ...

# %%
## information about the dataset
Earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10341 entries, 0 to 10340
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             10341 non-null  object
#  1   latitude         10341 non-null  float64
#  2   longitude        10341 non-null  float64
#  3   depth            10341 non-null  float64
#  4   mag              10339 non-null  float64
#  5   magType          10339 non-null  object
#  6   nst              8865 non-null   float64
#  7   gap              8865 non-null   float64
#  8   dmin             6845 non-null   float64
#  9   rms              10341 non-null  float64
#  10  net              10341 non-null  object
#  11  id               10341 non-null  object
#  12  updated          10341 non-null  object
#  13  place            10341 non-null  object
#  14  type             10341 non-null  object
#  15  horizontalError  7776 non-null   float64
# ...

# %%
## cheaking for missing value
Earthquake.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   2
# magType               2
# nst                1476
# gap                1476
# dmin               3496
# rms                   0
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2565
# depthError            2
# magError           1785
# magNst             1483
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
## drop missing value
Earthquake = Earthquake.dropna()

# %%
## know the mean, count...
Earthquake.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  5459.000000  5459.000000  5459.000000  5459.000000  5459.000000
# mean     33.345160   -89.418624    19.795084     1.795583    26.217989
# std      18.530613    73.188799    60.997125     1.535514    23.220771
# min     -62.969400  -179.937300    -3.260000    -0.740000     0.000000
# 25%      33.486167  -121.751083     3.430000     0.700000    12.000000
# 50%      37.334667  -116.674167     7.410000     1.190000    19.000000
# 75%      44.111750  -110.709833    10.935000     2.400000    32.000000
# max      82.475900   179.975200   638.038000     7.600000   269.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  5459.000000  5459.000000  5459.000000      5459.000000  5459.000000
# mean    107.191244     1.127301     0.237798         2.196553     2.934980
# std      57.439261     3.283442     0.255057         3.610593     6.368724
# ...

# %%
## correlation between all these varibles

Earthquake.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\3552425808.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Earthquake.corr()
#                  latitude  longitude     depth       mag       nst       gap  \
# latitude         1.000000  -0.388663 -0.451829 -0.510208 -0.205686  0.110053
# longitude       -0.388663   1.000000  0.197536  0.680486  0.340108 -0.028693
# depth           -0.451829   0.197536  1.000000  0.374122  0.173297 -0.040018
# mag             -0.510208   0.680486  0.374122  1.000000  0.580327 -0.089597
# nst             -0.205686   0.340108  0.173297  0.580327  1.000000 -0.384295
# gap              0.110053  -0.028693 -0.040018 -0.089597 -0.384295  1.000000
# dmin            -0.211167   0.424422  0.137480  0.593745  0.315056 -0.021729
# ...

# %%
Earthquake.corr()['mag']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\1073100986.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Earthquake.corr()['mag']
# latitude          -0.510208
# longitude          0.680486
# depth              0.374122
# mag                1.000000
# nst                0.580327
# gap               -0.089597
# dmin               0.593745
# rms                0.837349
# horizontalError    0.827473
# depthError         0.139990
# magError          -0.282159
# magNst             0.461781
# Name: mag, dtype: float64

# %%
## Heatwave of attributes in the data provided although some present with an error
sns.heatmap(Earthquake.corr(), annot = True)
plt.figure(figsize = (20,20))
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\1509669541.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Earthquake.corr(), annot = True)

# %%
## check the latitude of the earthquake
Earthquake.latitude.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        38.834999
# 2        33.290500
# 3        38.813168
# 4        18.864167
# 6        35.938333
#            ...
# 10335    44.780833
# 10336    44.779667
# 10338    44.784667
# 10339    44.776500
# 10340    28.898700
# Name: latitude, Length: 5459, dtype: float64>

# %%
## cheak the frequency of the earthquake 
Earthquake.mag.value_counts()
# Out:
#  4.50    165
#  4.40    144
#  4.60    143
#  4.30    117
#  4.70     82
#         ...
#  2.95      1
#  3.71      1
#  6.40      1
#  2.18      1
# -0.35      1
# Name: mag, Length: 419, dtype: int64

# %%
freq = Earthquake['mag'].value_counts()
freq
# Out:
#  4.50    165
#  4.40    144
#  4.60    143
#  4.30    117
#  4.70     82
#         ...
#  2.95      1
#  3.71      1
#  6.40      1
#  2.18      1
# -0.35      1
# Name: mag, Length: 419, dtype: int64

# %%
# plot the frequence 
fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])
ax.plot(freq)
Earthquake
# Out:
#                            time   latitude   longitude  depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666   2.16  1.44      md
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167  27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667   1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000   8.26  2.94      md
# 6      2022-10-18T12:03:39.890Z  35.938333 -117.703000   3.11  0.98      ml
# ...                         ...        ...         ...    ...   ...     ...
# 10335  2022-09-18T13:01:23.920Z  44.780833 -110.813833   5.41  1.36      md
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833   4.98  1.89      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000   5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333   5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600  10.00  4.50      mb
#
# ...

# %%
Earthquake['new_time'] =  pd.to_datetime(Earthquake['time']).dt.time
Earthquake['new_date'] = pd.to_datetime(Earthquake['time']).dt.date
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\2550374061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Earthquake['new_time'] =  pd.to_datetime(Earthquake['time']).dt.time
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\2550374061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Earthquake['new_date'] = pd.to_datetime(Earthquake['time']).dt.date

# %%
Earthquake.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2022-10-18T12:52:06.700Z  38.834999 -122.802666   2.16  1.44      md  26.0
# 2  2022-10-18T12:34:16.310Z  33.290500 -116.466167  27.95  1.12      ml   9.0
# 3  2022-10-18T12:21:13.340Z  38.813168 -122.827667   1.93  0.50      md  13.0
# 4  2022-10-18T12:19:20.670Z  18.864167  -67.181000   8.26  2.94      md  10.0
# 6  2022-10-18T12:03:39.890Z  35.938333 -117.703000   3.11  0.98      ml  12.0
#
#      gap      dmin   rms  ...        type horizontalError depthError  \
# 0   33.0  0.010210  0.04  ...  earthquake            0.20       0.41
# 2  127.0  0.046690  0.28  ...  earthquake            2.08       1.53
# 3   86.0  0.004453  0.02  ...  earthquake            0.32       0.69
# 4  274.0  0.400100  0.65  ...  earthquake            3.13       3.60
# 6  129.0  0.093720  0.08  ...  earthquake            0.26       0.67
#
#    magError magNst     status  locationSource  magSource         new_time  \
# ...

# %%
## creating place
Earthquake['new_place'] =  Earthquake['place'].str.split(',').str.get(1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3752\323074994.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Earthquake['new_place'] =  Earthquake['place'].str.split(',').str.get(1)

# %%
Earthquake.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2022-10-18T12:52:06.700Z  38.834999 -122.802666   2.16  1.44      md  26.0
# 2  2022-10-18T12:34:16.310Z  33.290500 -116.466167  27.95  1.12      ml   9.0
# 3  2022-10-18T12:21:13.340Z  38.813168 -122.827667   1.93  0.50      md  13.0
# 4  2022-10-18T12:19:20.670Z  18.864167  -67.181000   8.26  2.94      md  10.0
# 6  2022-10-18T12:03:39.890Z  35.938333 -117.703000   3.11  0.98      ml  12.0
#
#      gap      dmin   rms  ... depthError  magError magNst     status  \
# 0   33.0  0.010210  0.04  ...       0.41  0.110000    7.0  automatic
# 2  127.0  0.046690  0.28  ...       1.53  0.376000   10.0  automatic
# 3   86.0  0.004453  0.02  ...       0.69  0.360000    2.0  automatic
# 4  274.0  0.400100  0.65  ...       3.60  0.149442    9.0   reviewed
# 6  129.0  0.093720  0.08  ...       0.67  0.159000   12.0  automatic
#
#   locationSource  magSource         new_time    new_date     new_place month
# ...

# %%
depth = Earthquake['depth'].value_counts()
depth
# Out:
# 10.000    542
# 35.000     43
# 5.000      18
# 1.840      14
# 1.850      14
#          ...
# 35.340      1
# 11.140      1
# 0.650       1
# 12.325      1
# 10.489      1
# Name: depth, Length: 2310, dtype: int64

# %%
## histogram of depth majority of the earthquakes havea depth less than 30 
plt.hist(Earthquake['depth'],color = 'green',align = 'mid',bins = 30)
plt.ylabel('Number of occurances')
plt.title('Depth')
# Out:
# Text(0.5, 1.0, 'Depth')

# %%
## Analysis between longitude and latitidue aginst time 
f, ax = plt.subplots(figsize=(10, 5))
sns.scatterplot(x = 'latitude', y = 'longitude', data = Earthquake, hue = 'month', color = 'yellow')
plt.title('Bi-variate analysis between longitude and latitidue.')
plt.show()
Earthquake
# Out:
#                            time   latitude   longitude  depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666   2.16  1.44      md
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167  27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667   1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000   8.26  2.94      md
# 6      2022-10-18T12:03:39.890Z  35.938333 -117.703000   3.11  0.98      ml
# ...                         ...        ...         ...    ...   ...     ...
# 10335  2022-09-18T13:01:23.920Z  44.780833 -110.813833   5.41  1.36      md
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833   4.98  1.89      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000   5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333   5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600  10.00  4.50      mb
#
# ...

# %%
## Analysis between longitude and latitidue aginst time 
f, ax = plt.subplots(figsize=(10, 5))
plt.scatterplot(x = 'latitude', y = 'longitude', data = Earthquake, hue = 'month', color = 'yellow')
plt.title('Bi-variate analysis between longitude and latitidue.')
plt.show()
Earthquake
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [55], line 3
#       1 ## Analysis between longitude and latitidue aginst time
#       2 f, ax = plt.subplots(figsize=(10, 5))
# ----> 3 plt.scatterplot(x = 'latitude', y = 'longitude', data = Earthquake, hue = 'month', color = 'yellow')
#       4 plt.title('Bi-variate analysis between longitude and latitidue.')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
Earthquake.info
# Out:
# <bound method DataFrame.info of                            time   latitude   longitude  depth   mag magType  \
# 0      2022-10-18T12:52:06.700Z  38.834999 -122.802666   2.16  1.44      md
# 2      2022-10-18T12:34:16.310Z  33.290500 -116.466167  27.95  1.12      ml
# 3      2022-10-18T12:21:13.340Z  38.813168 -122.827667   1.93  0.50      md
# 4      2022-10-18T12:19:20.670Z  18.864167  -67.181000   8.26  2.94      md
# 6      2022-10-18T12:03:39.890Z  35.938333 -117.703000   3.11  0.98      ml
# ...                         ...        ...         ...    ...   ...     ...
# 10335  2022-09-18T13:01:23.920Z  44.780833 -110.813833   5.41  1.36      md
# 10336  2022-09-18T13:00:45.010Z  44.779667 -110.806833   4.98  1.89      ml
# 10338  2022-09-18T12:59:21.700Z  44.784667 -110.802000   5.95  0.93      md
# 10339  2022-09-18T12:58:59.670Z  44.776500 -110.804333   5.06  1.67      ml
# 10340  2022-09-18T12:57:56.064Z  28.898700   95.879600  10.00  4.50      mb
#
# ...

# %%
Earthquake.iloc[1:2]
# Out:
#                        time  latitude   longitude  depth   mag magType  nst  \
# 2  2022-10-18T12:34:16.310Z   33.2905 -116.466167  27.95  1.12      ml  9.0
#
#      gap     dmin   rms  ...                   updated  \
# 2  127.0  0.04669  0.28  ...  2022-10-18T12:37:49.760Z
#
#                             place        type horizontalError depthError  \
# 2  9km WNW of Borrego Springs, CA  earthquake            2.08       1.53
#
#    magError  magNst     status  locationSource magSource
# 2     0.376    10.0  automatic              ci        ci
#
# [1 rows x 22 columns]
